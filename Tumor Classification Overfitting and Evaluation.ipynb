# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1', data = df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar') #we want to see the correlation of different categorical data with the "y"
#ranked in increasing ascending order
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X = df.drop('benign_0__mal_1',axis = 1).values
y = df['benign_0__mal_1'].values

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X_train.shape #426 rolls and 30 features
# Out:
# (426, 30)

# %% [markdown]
# # Create the model

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

#the last layer needs to be a sigmoid function because we need the model to do binary classification
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %% [markdown]
# # Train the model

# %%
model.fit(x=X_train,y=y_train, epochs= 600, validation_data = (X_test,y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6824 - val_loss: 0.6648
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6570 - val_loss: 0.6402
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6326 - val_loss: 0.6071
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5995 - val_loss: 0.5758
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5671 - val_loss: 0.5373
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5316 - val_loss: 0.5014
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4958 - val_loss: 0.4621
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4593 - val_loss: 0.4252
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4235 - val_loss: 0.3860
# Epoch 10/600
# ...

# %% [markdown]
# ### Plot out the "Loss"

# %%
#we can plot out the training loss as well as the validation loss
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
#this is a typical case where the data has overfitted since so many epochs were run
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## To Prevent Overfitting - we need early stop

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

#the last layer needs to be a sigmoid function because we need the model to do binary classification
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
help(EarlyStopping)
# Out:
# Help on class EarlyStopping in module keras.callbacks:
#
# class EarlyStopping(Callback)
#  |  EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#  |
#  |  Stop training when a monitored metric has stopped improving.
#  |
#  |  Assuming the goal of a training is to minimize the loss. With this, the
#  |  metric to be monitored would be `'loss'`, and mode would be `'min'`. A
#  |  `model.fit()` training loop will check at end of every epoch whether
#  |  the loss is no longer decreasing, considering the `min_delta` and
#  |  `patience` if applicable. Once it's found no longer decreasing,
#  |  `model.stop_training` is marked True and the training terminates.
#  |
#  |  The quantity to be monitored needs to be available in `logs` dict.
#  |  To make it so, pass the loss or metrics at `model.compile()`.
#  |
#  |  Args:
#  |    monitor: Quantity to be monitored.
# ...

# %%
early_stop = EarlyStopping(monitor = 'val_loss',mode ='min', verbose = 1, patience = 25)

# %%
model.fit(x=X_train,y=y_train, epochs= 600, validation_data = (X_test,y_test),
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 7ms/step - loss: 0.7000 - val_loss: 0.6922
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6504 - val_loss: 0.6435
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6097 - val_loss: 0.5917
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5658 - val_loss: 0.5361
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5095 - val_loss: 0.4763
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4527 - val_loss: 0.4157
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4034 - val_loss: 0.3674
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3596 - val_loss: 0.3252
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3216 - val_loss: 0.2892
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.5))

#the last layer needs to be a sigmoid function because we need the model to do binary classification
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %%
model.fit(x=X_train,y=y_train, epochs= 600, validation_data = (X_test,y_test),
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7117 - val_loss: 0.6759
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6892 - val_loss: 0.6597
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6734 - val_loss: 0.6413
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6646 - val_loss: 0.6228
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6309 - val_loss: 0.6024
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6145 - val_loss: 0.5800
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5930 - val_loss: 0.5539
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5705 - val_loss: 0.5157
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5439 - val_loss: 0.4797
# Epoch 10/600
# ...

# %%
model_loss_2 = pd.DataFrame(model.history.history)

# %%
model_loss_2.plot()
# Out:
# <AxesSubplot:>

# %%
predictions = model.predict(X_test)

# %%
y_pred = np.where(predictions > 0.5, 1,0)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90        55
#            1       0.99      0.88      0.93        88
#
#     accuracy                           0.92       143
#    macro avg       0.91      0.93      0.91       143
# weighted avg       0.93      0.92      0.92       143

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[54  1]
#  [11 77]]
